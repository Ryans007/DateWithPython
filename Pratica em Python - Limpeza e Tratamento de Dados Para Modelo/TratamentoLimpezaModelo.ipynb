# %%
#Importação das bibliotecas

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importação dos dados

dataset = pd.read_csv('AmazonFineFoodReviews.csv', sep=',')
dataset.head()
# Out:
#            UserId   ProductId      Id                       Summary  Score  \
# 0  A12UO92HK8IFY1  B005FH3XCA  142228       Crazy for this cracker!      5
# 1  A12UTFBYVPDD49  B003FDG4K4  404031  Drinks were chalky at bottom      2
# 2  A17X91STB6652Z  B00020HHM2  293865        Hetrbal Teas,Chamomile      5
# 3  A17X91STB6652Z  B00073IVAQ  178249        Hetrbal Teas,Chamomile      5
# 4  A17X91STB6652Z  B00073JVFU  386242        Hetrbal Teas,Chamomile      5
#
#    HelpfulnessDenominator          ProfileName  HelpfulnessNumerator  \
# 0                       1         Gfree Stacey                     1
# 1                      10         Paul Shelton                     5
# 2                       0  Michael E. Califfsr                     0
# 3                       0  Michael E. Califfsr                     0
# 4                       0  Michael E. Califfsr                     0
#
#                   Time                                        Description  \
# ...
